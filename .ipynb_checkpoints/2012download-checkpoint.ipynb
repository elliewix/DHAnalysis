# %%
import urllib2
from scrapy.selector import Selector
from os import listdir
from os.path import isfile, join

# %%
def dlpage(url, targetname):
    """pass url and file name, downloads url page to this file"""
    file(targetname, "wb").write(urllib2.urlopen(url).read())
    
def getFiles(path):
    """Function to return a list of all files within a folder"""
    files = [ f for f in listdir(path) if isfile(join(path,f)) and f[0] != '.' ]
    return files

# %%
# Download the search pages

# %%
baseurl = 'http://dh2011abstracts.stanford.edu/xtf/search?browse-all=yes;startDoc='
urls = {'DH2012/source/2012search' + str(i) + '.txt': baseurl + str(i) for i in range(1, 142, 10)}

# %%
for target, url in urls.iteritems():
    dlpage(url, target)
    #print target

# %%
base = 'DH2012/source/'
searchpages = [base + x for x in getFiles(base)]
#print searchpages

# %%
# Extract the abstract URLs from the search pages
# and download those abstract files

# %%
foundlinks = []

for f in searchpages:
    with open(f, 'rt') as text:
        body = text.read()
        pages = Selector(text=body).xpath('//a[starts-with(@href,\'view?docId=tei/\')]/@href').extract()
        foundlinks += pages

# %%
#print foundlinks

# %%
urlbase = 'http://dh2011abstracts.stanford.edu/xtf/'
aburls = [urlbase + u for u in foundlinks]
#print aburls

# %%
abbase = 'DH2012/abstracts'
for url in aburls:
    filename = url.split('/')[-1].split(';')[0]
    #dlpage(url, abbase + filename)

# %%
# get just the text

# %%
removethings = ['<em>','</em>','<b>','</b>','<i>','</i>']

totalconfthings = 0
totalpython = 0
totaljavascript = 0
totaljava = 0
totalcuration = 0

files = [abbase + f for f in getFiles(abbase)]

for ab in files:
    print ab
    name = ab.split('/')[-1].split('.')[0]
    print name
    with open("abstracts/" + ab,'rb') as abfile:
        body = abfile.read()
    for each in removethings:
        body = body.replace(each, '')
    text = "\n".join(Selector(text=body).xpath('//div[@class=\'results\'//text()').extract())
#     if ab.endswith('.xml'):
#         totalconfthings += 1
#         if 'python' in text.lower():
#             totalpython += 1
#             print ab, 'python'
#         if 'javascript' in text.lower():
#             totaljavascript += 1
#             print ab, 'javascript'
#         elif 'java' in text.lower():
#             totaljava += 1
#             print ab, 'java' # there is some weakness in how I'm doing this calculation.  TODO: fix that
#         if 'curation' in text.lower():
#             print ab, 'curation'
#             totalcuration += 1
#     with open("abstracts/" + name + ".txt", 'wt') as about:
#         about.write(text.encode('utf8'))
# Out:
# DH2012/abstractsabstractsab-002.xml
# abstractsabstractsab-002
# DH2012/abstractsabstractsab-003.xml
# abstractsabstractsab-003
# DH2012/abstractsabstractsab-004.xml
# abstractsabstractsab-004
# DH2012/abstractsabstractsab-005.xml
# abstractsabstractsab-005
# DH2012/abstractsabstractsab-006.xml
# abstractsabstractsab-006
# DH2012/abstractsabstractsab-007.xml
# abstractsabstractsab-007
# DH2012/abstractsabstractsab-008.xml
# abstractsabstractsab-008
# DH2012/abstractsabstractsab-009.xml
# abstractsabstractsab-009
# DH2012/abstractsabstractsab-102.xml
# abstractsabstractsab-102
# DH2012/abstractsabstractsab-104.xml
# abstractsabstractsab-104
# DH2012/abstractsabstractsab-106.xml
# abstractsabstractsab-106
# DH2012/abstractsabstractsab-110.xml
# abstractsabstractsab-110
# DH2012/abstractsabstractsab-113.xml
# abstractsabstractsab-113
# DH2012/abstractsabstractsab-114.xml
# abstractsabstractsab-114
# DH2012/abstractsabstractsab-115.xml
# abstractsabstractsab-115
# DH2012/abstractsabstractsab-120.xml
# abstractsabstractsab-120
# DH2012/abstractsabstractsab-121.xml
# abstractsabstractsab-121
# DH2012/abstractsabstractsab-122.xml
# abstractsabstractsab-122
# DH2012/abstractsabstractsab-124.xml
# abstractsabstractsab-124
# DH2012/abstractsabstractsab-128.xml
# abstractsabstractsab-128
# DH2012/abstractsabstractsab-129.xml
# abstractsabstractsab-129
# DH2012/abstractsabstractsab-130.xml
# abstractsabstractsab-130
# DH2012/abstractsabstractsab-131.xml
# abstractsabstractsab-131
# DH2012/abstractsabstractsab-132.xml
# abstractsabstractsab-132
# DH2012/abstractsabstractsab-136.xml
# abstractsabstractsab-136
# DH2012/abstractsabstractsab-137.xml
# abstractsabstractsab-137
# DH2012/abstractsabstractsab-138.xml
# abstractsabstractsab-138
# DH2012/abstractsabstractsab-142.xml
# abstractsabstractsab-142
# DH2012/abstractsabstractsab-143.xml
# abstractsabstractsab-143
# DH2012/abstractsabstractsab-144.xml
# abstractsabstractsab-144
# DH2012/abstractsabstractsab-150.xml
# abstractsabstractsab-150
# DH2012/abstractsabstractsab-153.xml
# abstractsabstractsab-153
# DH2012/abstractsabstractsab-154.xml
# abstractsabstractsab-154
# DH2012/abstractsabstractsab-158.xml
# abstractsabstractsab-158
# DH2012/abstractsabstractsab-160.xml
# abstractsabstractsab-160
# DH2012/abstractsabstractsab-162.xml
# abstractsabstractsab-162
# DH2012/abstractsabstractsab-166.xml
# abstractsabstractsab-166
# DH2012/abstractsabstractsab-167.xml
# abstractsabstractsab-167
# DH2012/abstractsabstractsab-168.xml
# abstractsabstractsab-168
# DH2012/abstractsabstractsab-173.xml
# abstractsabstractsab-173
# DH2012/abstractsabstractsab-174.xml
# abstractsabstractsab-174
# DH2012/abstractsabstractsab-175.xml
# abstractsabstractsab-175
# DH2012/abstractsabstractsab-177.xml
# abstractsabstractsab-177
# DH2012/abstractsabstractsab-179.xml
# abstractsabstractsab-179
# DH2012/abstractsabstractsab-181.xml
# abstractsabstractsab-181
# DH2012/abstractsabstractsab-182.xml
# abstractsabstractsab-182
# DH2012/abstractsabstractsab-183.xml
# abstractsabstractsab-183
# DH2012/abstractsabstractsab-184.xml
# abstractsabstractsab-184
# DH2012/abstractsabstractsab-186.xml
# abstractsabstractsab-186
# DH2012/abstractsabstractsab-192.xml
# abstractsabstractsab-192
# DH2012/abstractsabstractsab-193.xml
# abstractsabstractsab-193
# DH2012/abstractsabstractsab-195.xml
# abstractsabstractsab-195
# DH2012/abstractsabstractsab-196.xml
# abstractsabstractsab-196
# DH2012/abstractsabstractsab-197.xml
# abstractsabstractsab-197
# DH2012/abstractsabstractsab-198.xml
# abstractsabstractsab-198
# DH2012/abstractsabstractsab-201.xml
# abstractsabstractsab-201
# DH2012/abstractsabstractsab-202.xml
# abstractsabstractsab-202
# DH2012/abstractsabstractsab-204.xml
# abstractsabstractsab-204
# DH2012/abstractsabstractsab-205.xml
# abstractsabstractsab-205
# DH2012/abstractsabstractsab-206.xml
# abstractsabstractsab-206
# DH2012/abstractsabstractsab-208.xml
# abstractsabstractsab-208
# DH2012/abstractsabstractsab-210.xml
# abstractsabstractsab-210
# DH2012/abstractsabstractsab-211.xml
# abstractsabstractsab-211
# DH2012/abstractsabstractsab-212.xml
# abstractsabstractsab-212
# DH2012/abstractsabstractsab-214.xml
# abstractsabstractsab-214
# DH2012/abstractsabstractsab-215.xml
# abstractsabstractsab-215
# DH2012/abstractsabstractsab-217.xml
# abstractsabstractsab-217
# DH2012/abstractsabstractsab-220.xml
# abstractsabstractsab-220
# DH2012/abstractsabstractsab-221.xml
# abstractsabstractsab-221
# DH2012/abstractsabstractsab-222.xml
# abstractsabstractsab-222
# DH2012/abstractsabstractsab-223.xml
# abstractsabstractsab-223
# DH2012/abstractsabstractsab-224.xml
# abstractsabstractsab-224
# DH2012/abstractsabstractsab-227.xml
# abstractsabstractsab-227
# DH2012/abstractsabstractsab-229.xml
# abstractsabstractsab-229
# DH2012/abstractsabstractsab-230.xml
# abstractsabstractsab-230
# DH2012/abstractsabstractsab-231.xml
# abstractsabstractsab-231
# DH2012/abstractsabstractsab-232.xml
# abstractsabstractsab-232
# DH2012/abstractsabstractsab-233.xml
# abstractsabstractsab-233
# DH2012/abstractsabstractsab-234.xml
# abstractsabstractsab-234
# DH2012/abstractsabstractsab-235.xml
# abstractsabstractsab-235
# DH2012/abstractsabstractsab-237.xml
# abstractsabstractsab-237
# DH2012/abstractsabstractsab-242.xml
# abstractsabstractsab-242
# DH2012/abstractsabstractsab-245.xml
# abstractsabstractsab-245
# DH2012/abstractsabstractsab-250.xml
# abstractsabstractsab-250
# DH2012/abstractsabstractsab-251.xml
# abstractsabstractsab-251
# DH2012/abstractsabstractsab-254.xml
# abstractsabstractsab-254
# DH2012/abstractsabstractsab-255.xml
# abstractsabstractsab-255
# DH2012/abstractsabstractsab-257.xml
# abstractsabstractsab-257
# DH2012/abstractsabstractsab-258.xml
# abstractsabstractsab-258
# DH2012/abstractsabstractsab-260.xml
# abstractsabstractsab-260
# DH2012/abstractsabstractsab-261.xml
# abstractsabstractsab-261
# DH2012/abstractsabstractsab-263.xml
# abstractsabstractsab-263
# DH2012/abstractsabstractsab-264.xml
# abstractsabstractsab-264
# DH2012/abstractsabstractsab-265.xml
# abstractsabstractsab-265
# DH2012/abstractsabstractsab-266.xml
# abstractsabstractsab-266
# DH2012/abstractsabstractsab-268.xml
# abstractsabstractsab-268
# DH2012/abstractsabstractsab-269.xml
# abstractsabstractsab-269
# DH2012/abstractsabstractsab-271.xml
# abstractsabstractsab-271
# DH2012/abstractsabstractsab-276.xml
# abstractsabstractsab-276
# DH2012/abstractsabstractsab-279.xml
# abstractsabstractsab-279
# DH2012/abstractsabstractsab-285.xml
# abstractsabstractsab-285
# DH2012/abstractsabstractsab-289.xml
# abstractsabstractsab-289
# DH2012/abstractsabstractsab-290.xml
# abstractsabstractsab-290
# DH2012/abstractsabstractsab-293.xml
# abstractsabstractsab-293
# DH2012/abstractsabstractsab-296.xml
# abstractsabstractsab-296
# DH2012/abstractsabstractsab-297.xml
# abstractsabstractsab-297
# DH2012/abstractsabstractsab-298.xml
# abstractsabstractsab-298
# DH2012/abstractsabstractsab-299.xml
# abstractsabstractsab-299
# DH2012/abstractsabstractsab-300.xml
# abstractsabstractsab-300
# DH2012/abstractsabstractsab-302.xml
# abstractsabstractsab-302
# DH2012/abstractsabstractsab-305.xml
# abstractsabstractsab-305
# DH2012/abstractsabstractsab-308.xml
# abstractsabstractsab-308
# DH2012/abstractsabstractsab-309.xml
# abstractsabstractsab-309
# DH2012/abstractsabstractsab-311.xml
# abstractsabstractsab-311
# DH2012/abstractsabstractsab-315.xml
# abstractsabstractsab-315
# DH2012/abstractsabstractsab-316.xml
# abstractsabstractsab-316
# DH2012/abstractsabstractsab-317.xml
# abstractsabstractsab-317
# DH2012/abstractsabstractsab-321.xml
# abstractsabstractsab-321
# DH2012/abstractsabstractsab-324.xml
# abstractsabstractsab-324
# DH2012/abstractsabstractsab-326.xml
# abstractsabstractsab-326
# DH2012/abstractsabstractsab-328.xml
# abstractsabstractsab-328
# DH2012/abstractsabstractsab-329.xml
# abstractsabstractsab-329
# DH2012/abstractsabstractsab-331.xml
# abstractsabstractsab-331
# DH2012/abstractsabstractsab-332.xml
# abstractsabstractsab-332
# DH2012/abstractsabstractsab-333.xml
# abstractsabstractsab-333
# DH2012/abstractsabstractsab-335.xml
# abstractsabstractsab-335
# DH2012/abstractsabstractsab-336.xml
# abstractsabstractsab-336
# DH2012/abstractsabstractsab-338.xml
# abstractsabstractsab-338
# DH2012/abstractsabstractsab-339.xml
# abstractsabstractsab-339
# DH2012/abstractsabstractsab-342.xml
# abstractsabstractsab-342
# DH2012/abstractsabstractsab-343.xml
# abstractsabstractsab-343
# DH2012/abstractsabstractsab-346.xml
# abstractsabstractsab-346
# DH2012/abstractsabstractsab-347.xml
# abstractsabstractsab-347
# DH2012/abstractsabstractsab-349.xml
# abstractsabstractsab-349
# DH2012/abstractsabstractsab-350.xml
# abstractsabstractsab-350
# DH2012/abstractsabstractsab-351.xml
# abstractsabstractsab-351
# DH2012/abstractsabstractsab-352.xml
# abstractsabstractsab-352
# DH2012/abstractsabstractsab-360.xml
# abstractsabstractsab-360
# DH2012/abstractsabstractsab-361.xml
# abstractsabstractsab-361
# DH2012/abstractsabstractsab-362.xml
# abstractsabstractsab-362
# DH2012/abstractsabstractsab-367.xml
# abstractsabstractsab-367
# DH2012/abstractsabstractsab-368.xml
# abstractsabstractsab-368
# DH2012/abstractsabstractsab-370.xml
# abstractsabstractsab-370
# DH2012/abstractsabstractsab-372.xml
# abstractsabstractsab-372
# DH2012/abstractsabstractsab-375.xml
# abstractsabstractsab-375
# DH2012/abstractsabstractsab-381.xml
# abstractsabstractsab-381
# DH2012/abstractsabstractsab-382.xml
# abstractsabstractsab-382
# DH2012/abstractsabstractsab-383.xml
# abstractsabstractsab-383
# DH2012/abstractsabstractsab-385.xml
# abstractsabstractsab-385
# DH2012/abstractsabstractsab-388.xml
# abstractsabstractsab-388
# DH2012/abstractsabstractsab-390.xml
# abstractsabstractsab-390
# DH2012/abstractsabstractsab-394.xml
# abstractsabstractsab-394
