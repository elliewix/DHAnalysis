# %%
import urllib2
from scrapy.selector import Selector
from os import listdir
from os.path import isfile, join

# %%
def dlpage(url, targetname):
    """pass url and file name, downloads url page to this file"""
    file(targetname, "wb").write(urllib2.urlopen(url).read())
    
def getFiles(path):
    """Function to return a list of all files within a folder"""
    files = [ f for f in listdir(path) if isfile(join(path,f)) and f[0] != '.' ]
    return files

# %%
# Download the search pages

# %%
baseurl = 'http://dh2011abstracts.stanford.edu/xtf/search?browse-all=yes;startDoc='
urls = {'DH2012/source/2011search' + str(i) + '.txt': baseurl + str(i) for i in range(1, 142, 10)}

# %%
for target, url in urls.iteritems():
    dlpage(url, target)
    #print target

# %%
base = 'DH2011/source/'
searchpages = [base + x for x in getFiles(base)]
#print searchpages

# %%
# Extract the abstract URLs from the search pages
# and download those abstract files

# %%
foundlinks = []

for f in searchpages:
    with open(f, 'rt') as text:
        body = text.read()
        pages = Selector(text=body).xpath('//a[starts-with(@href,\'view?docId=tei/\')]/@href').extract()
        foundlinks += pages

# %%
#print foundlinks

# %%
urlbase = 'http://dh2011abstracts.stanford.edu/xtf/'
aburls = [urlbase + u for u in foundlinks]
#print aburls

# %%
abbase = 'DH2011/abstracts/'
for url in aburls:
    filename = url.split('/')[-1].split(';')[0]
    #dlpage(url, abbase + filename)

# %%
# get just the text

# %%
removethings = ['<em>','</em>','<b>','</b>','<i>','</i>']

totalconfthings = 0
totalpython = 0
totaljavascript = 0
totaljava = 0
totalcuration = 0

files = [abbase + f for f in getFiles(abbase)]

for ab in files:
    print ab
    name = ab.split('/')[-1].split('.')[0]
    print name
    with open(ab,'rb') as abfile:
        body = abfile.read()
    for each in removethings:
        body = body.replace(each, '')
    text = "\n".join(Selector(text=body).xpath('//div[@class=\'results\']//text()').extract())
    with open('DH2011/abstractext/' + name + '.txt', 'wt') as abwrite:
        abwrite.write(text.encode('utf8'))
#     if ab.endswith('.xml'):
#         totalconfthings += 1
#         if 'python' in text.lower():
#             totalpython += 1
#             print ab, 'python'
#         if 'javascript' in text.lower():
#             totaljavascript += 1
#             print ab, 'javascript'
#         elif 'java' in text.lower():
#             totaljava += 1
#             print ab, 'java' # there is some weakness in how I'm doing this calculation.  TODO: fix that
#         if 'curation' in text.lower():
#             print ab, 'curation'
#             totalcuration += 1
#     with open("abstracts/" + name + ".txt", 'wt') as about:
#         about.write(text.encode('utf8'))
# Out:
# DH2011/abstracts/ab-002.xml
# ab-002
# DH2011/abstracts/ab-003.xml
# ab-003
# DH2011/abstracts/ab-004.xml
# ab-004
# DH2011/abstracts/ab-005.xml
# ab-005
# DH2011/abstracts/ab-006.xml
# ab-006
# DH2011/abstracts/ab-007.xml
# ab-007
# DH2011/abstracts/ab-008.xml
# ab-008
# DH2011/abstracts/ab-009.xml
# ab-009
# DH2011/abstracts/ab-102.xml
# ab-102
# DH2011/abstracts/ab-104.xml
# ab-104
# DH2011/abstracts/ab-106.xml
# ab-106
# DH2011/abstracts/ab-110.xml
# ab-110
# DH2011/abstracts/ab-113.xml
# ab-113
# DH2011/abstracts/ab-114.xml
# ab-114
# DH2011/abstracts/ab-115.xml
# ab-115
# DH2011/abstracts/ab-120.xml
# ab-120
# DH2011/abstracts/ab-121.xml
# ab-121
# abstractsab-279
# DH2011/abstracts/abstractsab-285.xml
# abstractsab-285
# DH2011/abstracts/abstractsab-289.xml
# abstractsab-289
# DH2011/abstracts/abstractsab-290.xml
# abstractsab-290
# DH2011/abstracts/abstractsab-293.xml
# abstractsab-293
# DH2011/abstracts/abstractsab-296.xml
# abstractsab-296
# DH2011/abstracts/abstractsab-297.xml
# abstractsab-297
# DH2011/abstracts/abstractsab-298.xml
# abstractsab-298
# DH2011/abstracts/abstractsab-299.xml
# abstractsab-299
# DH2011/abstracts/abstractsab-300.xml
# abstractsab-300
# DH2011/abstracts/abstractsab-302.xml
# abstractsab-302
# DH2011/abstracts/abstractsab-305.xml
# abstractsab-305
# DH2011/abstracts/abstractsab-308.xml
# abstractsab-308
# DH2011/abstracts/abstractsab-309.xml
# abstractsab-309
# DH2011/abstracts/abstractsab-311.xml
# abstractsab-311
# DH2011/abstracts/abstractsab-315.xml
# abstractsab-315
# DH2011/abstracts/abstractsab-316.xml
# abstractsab-316
# DH2011/abstracts/abstractsab-317.xml
# abstractsab-317
# DH2011/abstracts/abstractsab-321.xml
# abstractsab-321
# DH2011/abstracts/abstractsab-324.xml
# abstractsab-324
# DH2011/abstracts/abstractsab-326.xml
# abstractsab-326
# DH2011/abstracts/abstractsab-328.xml
# abstractsab-328
# DH2011/abstracts/abstractsab-329.xml
# abstractsab-329
# DH2011/abstracts/abstractsab-331.xml
# abstractsab-331
# DH2011/abstracts/abstractsab-332.xml
# abstractsab-332
# DH2011/abstracts/abstractsab-333.xml
# abstractsab-333
# DH2011/abstracts/abstractsab-335.xml
# abstractsab-335
# DH2011/abstracts/abstractsab-336.xml
# abstractsab-336
# DH2011/abstracts/abstractsab-338.xml
# abstractsab-338
# DH2011/abstracts/abstractsab-339.xml
# abstractsab-339
# DH2011/abstracts/abstractsab-342.xml
# abstractsab-342
# DH2011/abstracts/abstractsab-343.xml
# abstractsab-343
# DH2011/abstracts/abstractsab-346.xml
# abstractsab-346
# DH2011/abstracts/abstractsab-347.xml
# abstractsab-347
# DH2011/abstracts/abstractsab-349.xml
# abstractsab-349
# DH2011/abstracts/abstractsab-350.xml
# abstractsab-350
# DH2011/abstracts/abstractsab-351.xml
# abstractsab-351
# DH2011/abstracts/abstractsab-352.xml
# abstractsab-352
# DH2011/abstracts/abstractsab-360.xml
# abstractsab-360
# DH2011/abstracts/abstractsab-361.xml
# abstractsab-361
# DH2011/abstracts/abstractsab-362.xml
# abstractsab-362
# DH2011/abstracts/abstractsab-367.xml
# abstractsab-367
# DH2011/abstracts/abstractsab-368.xml
# abstractsab-368
# DH2011/abstracts/abstractsab-370.xml
# abstractsab-370
# DH2011/abstracts/abstractsab-372.xml
# abstractsab-372
# DH2011/abstracts/abstractsab-375.xml
# abstractsab-375
# DH2011/abstracts/abstractsab-381.xml
# abstractsab-381
# DH2011/abstracts/abstractsab-382.xml
# abstractsab-382
# DH2011/abstracts/abstractsab-383.xml
# abstractsab-383
# DH2011/abstracts/abstractsab-385.xml
# abstractsab-385
# DH2011/abstracts/abstractsab-388.xml
# abstractsab-388
# DH2011/abstracts/abstractsab-390.xml
# abstractsab-390
# DH2011/abstracts/abstractsab-394.xml
# abstractsab-394
